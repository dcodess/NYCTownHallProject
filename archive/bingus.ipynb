# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
data = pd.read_csv("clean2.csv")

# %%
data
# Out:
#                           sub_boro_names     boro_names  median_rent  \
# 0                                Astoria         Queens      2125.10
# 1                              Bay Ridge       Brooklyn      1678.72
# 2                    Bayside/Little Neck         Queens      1962.32
# 3                     Bedford Stuyvesant       Brooklyn      2288.53
# 4                            Bensonhurst       Brooklyn      1496.61
# 5                           Borough Park       Brooklyn      1761.92
# 6           Brooklyn Heights/Fort Greene       Brooklyn      2842.83
# 7                 Brownsville/Ocean Hill       Brooklyn      1613.96
# 8                               Bushwick       Brooklyn      2162.30
# 9                         Central Harlem      Manhattan      2045.31
# 10               Chelsea/Clinton/Midtown      Manhattan      3545.57
# 11                          Coney Island       Brooklyn      1593.55
# 12                         East Flatbush       Brooklyn      1538.30
# ...
